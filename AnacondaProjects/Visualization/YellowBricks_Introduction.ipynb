# %%
import os.path
import datetime
from mlsettings.settings import load_app_config, get_datafolder_path

# %%
load_app_config()

# %%
ds_path = get_datafolder_path()

# %%
data_home =os.path.join(ds_path,'credit_yellow')

# %%
data_home =str(data_home)

# %%
from yellowbrick.datasets import load_credit

# %%
X, y = load_credit()

# %%
from yellowbrick.features import Rank1D

# %%
visualizer = Rank1D(algorithm='shapiro')

visualizer.fit(X, y)           # Fit the data to the visualizer
visualizer.transform(X)        # Transform the data
visualizer.show()              # Finalize and render the figure
# Out:
# D:\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1660: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# D:\Anaconda3\lib\site-packages\yellowbrick\features\rankd.py:216: YellowbrickWarning: RankD plots may be clipped when using matplotlib v3.1.1, upgrade to matplotlib v3.1.2 or later to fix the plots.
#   warnings.warn(msg, YellowbrickWarning)

# %%
predicted_classes =[0,1]

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from yellowbrick.classifier import ClassificationReport,ConfusionMatrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
bayes = GaussianNB()
visualizer = ClassificationReport(bayes, classes=predicted_classes)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
g = visualizer.poof()

# %%
lr =LogisticRegression()
visualizer = ClassificationReport(lr, classes=predicted_classes)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
g = visualizer.poof()
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
