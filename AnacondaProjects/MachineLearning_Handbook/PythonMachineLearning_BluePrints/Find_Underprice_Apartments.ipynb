# %%
import numpy as np 
import pandas as pd 
import requests 
import matplotlib.pyplot as plt 
from tqdm import tqdm
# %matplotlib inline

# %%
r = requests.get('https://www.renthop.com/listings/e-39th-st/19c/14892083')

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.content, "html.parser")

# %%
listing_divs = soup.select('div[class*=search-info]')

# %%
len(listing_divs)
# Out:
# 13

# %%
def parse_data(listing_divs):
    listing_list = [] 
    for idx in range(len(listing_divs)):
        indv_listing = []
        current_listing = listing_divs[idx]
        href = current_listing.select('a[id*=title]')[0]['href'] 
        addy = current_listing.select('a[id*=title]')[0].string 
        hood = current_listing.select('div[id*=hood]')[0].string.replace('\n','') 
        indv_listing.append(href)
        indv_listing.append(addy)
        indv_listing.append(hood)

        listing_specs = current_listing.select('table[id*=info] tr') 

        for spec in listing_specs:
            try: 
                #print(spec.text.replace(' ', '_').split())
                parts =spec.text.replace(' ', '').split()
                if len(parts)==4:
                    parts[3],parts[2] =parts[2],parts[3]
                #print(parts)
                indv_listing.extend(parts) 
            except: 
                indv_listing.extend(np.nan) 
        listing_list.append(indv_listing)  
    return listing_list

# %%
listing_list = parse_data(listing_divs)

# %%
url_prefix = "https://www.renthop.com/search/nyc?max_price=50000&min_price=0&page=" 
page_no = 1 
url_suffix = "&sort=hopscore&q=&search=0"

# %%
all_pages_parsed = [] 
for i in tqdm(range(1,101)): 
    page_no = i 
    target_page = url_prefix + str(page_no) + url_suffix 
     
    r = requests.get(target_page) 
     
    soup = BeautifulSoup(r.content, 'html.parser') 
     
    listing_divs = soup.select('div[class*=search-info]') 
     
    one_page_parsed = parse_data(listing_divs) 
     
    all_pages_parsed.extend(one_page_parsed)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [02:29<00:00,  1.46s/it]

# %%
all_pages_parsed[0]
# Out:
# ['https://www.renthop.com/listings/332-e-109th-street/5/15169991',
#  '331 E 109th St, Apt 5',
#  'East Harlem, Upper Manhattan, Manhattan',
#  '$2,250',
#  '2Bed',
#  '1Bath']

# %%
rent_listing_df  = pd.DataFrame(all_pages_parsed,columns=['url', 'address', 'neighborhood', 'rent','bed','baths','Additional'])
rent_listing_df.head()
# Out:
#                                                  url  \
# 0  https://www.renthop.com/listings/332-e-109th-s...
# 1  https://www.renthop.com/listings/74-macdonough...
# 2  https://www.renthop.com/listings/167-west-10th...
# 3  https://www.renthop.com/listings/w-191-street/...
# 4  https://www.renthop.com/listings/1385-york-ave...
#
#                              address  \
# 0              331 E 109th St, Apt 5
# 1            74 Macdonough St, Apt 4
# 2  167 West 10th Street, Apt TOWN...
# 3                       W 191 Street
# 4               1385 York Ave, Apt G
#
#                                         neighborhood    rent   bed  baths  \
# 0            East Harlem, Upper Manhattan, Manhattan  $2,250  2Bed  1Bath
# 1    Bedford-Stuyvesant, Northern Brooklyn, Brooklyn  $2,750  2Bed  2Bath
# 2        West Village, Downtown Manhattan, Manhattan  $9,995  3Bed  2Bath
# 3  Fort George, Washington Heights, Upper Manhatt...  $1,568  1Bed  1Bath
# 4        Upper East Side, Upper Manhattan, Manhattan  $6,995  2Bed  3Bath
#
#   Additional
# 0       None
# 1       None
# 2       None
# 3       None
# 4     /Flex3

# %%
rent_listing_df[rent_listing_df['Additional'].notnull()].head()
# Out:
#                                                   url  \
# 4   https://www.renthop.com/listings/1385-york-ave...
# 11  https://www.renthop.com/listings/82-76-116th-s...
# 24  https://www.renthop.com/listings/82-76-116th-s...
# 75  https://www.renthop.com/listings/550-west-140t...
# 85  https://www.renthop.com/listings/550-west-140t...
#
#                               address  \
# 4                1385 York Ave, Apt G
# 11  82-76 116th Street, Kew Garden...
# 24  82-76 116th Street, Kew Garden...
# 75       550 West 140th Street, Apt 2
# 85       550 West 140th Street, Apt 2
#
#                                          neighborhood    rent     bed  baths  \
# 4         Upper East Side, Upper Manhattan, Manhattan  $6,995    2Bed  3Bath
# 11           Kew Gardens, Northeastern Queens, Queens  $2,756    2Bed  2Bath
# 24           Kew Gardens, Northeastern Queens, Queens  $2,756    2Bed  2Bath
# 75  Hamilton Heights, West Harlem, Upper Manhattan...  $1,984  Studio  1Bath
# 85  Hamilton Heights, West Harlem, Upper Manhattan...  $1,984  Studio  1Bath
#
#    Additional
# 4      /Flex3
# 11     /Flex3
# 24     /Flex3
# 75     /Flex1
# 85     /Flex1

# %%
rent_listing_df['bed'].value_counts()
# Out:
# 1Bed      688
# 2Bed      591
# Studio    322
# 3Bed      281
# 4Bed       87
# Room       13
# 5Bed       10
# Loft        6
# 7Bed        1
# 6Bed        1
# Name: bed, dtype: int64

# %%
rent_listing_df['baths'].value_counts()
# Out:
# 1Bath      1485
# 2Bath       424
# 3Bath        53
# 1.5Bath      18
# 2.5Bath      10
# 4Bath         6
# 7Bath         2
# 5Bath         1
# 3.5Bath       1
# Name: baths, dtype: int64

# %%
rent_listing_df['rent'] = rent_listing_df['rent'].map(lambda x: str(x).replace('$','').replace(',','')).astype('int')

# %%
rent_listing_df['bed'] = rent_listing_df['bed'].map(lambda x: x.replace('Bed',''))
rent_listing_df['bed'] = rent_listing_df['bed'].map(lambda x: x.replace('Studio','0'))
rent_listing_df['bed'] = rent_listing_df['bed'].map(lambda x: x.replace('Room','0'))
rent_listing_df['bed'] = rent_listing_df['bed'].map(lambda x: x.replace('Loft','0')).astype(int)

# %%
rent_listing_df['baths'] = rent_listing_df['baths'].map(lambda x: x.replace('Bath','')).astype(float)

# %%
rent_listing_df.describe()
# Out:
#                rent          bed        baths
# count   2000.000000  2000.000000  2000.000000
# mean    4073.345000     1.562000     1.295250
# std     2423.338656     1.102163     0.564457
# min      880.000000     0.000000     1.000000
# 25%     2750.000000     1.000000     1.000000
# 50%     3543.000000     1.000000     1.000000
# 75%     4727.500000     2.000000     1.500000
# max    49500.000000     7.000000     7.000000

# %%
rent_listing_df['neighborhood'] = rent_listing_df['neighborhood'].map(lambda x: x.strip())

# %%
rent_listing_df.groupby('neighborhood')['rent'].count().to_frame('count').sort_values(by='count', ascending=False)
# Out:
#                                                     count
# neighborhood
# Hell's Kitchen, Midtown Manhattan, Manhattan          155
# Upper East Side, Upper Manhattan, Manhattan           108
# Yorkville, Upper East Side, Upper Manhattan, Ma...    100
# Murray Hill, Midtown Manhattan, Manhattan              96
# Financial District, Downtown Manhattan, Manhattan      93
# Lincoln Square, Upper West Side, Upper Manhatta...     75
# Bedford-Stuyvesant, Northern Brooklyn, Brooklyn        66
# Upper West Side, Upper Manhattan, Manhattan            64
# West Village, Downtown Manhattan, Manhattan            56
# East Village, Downtown Manhattan, Manhattan            51
# Bushwick, Northern Brooklyn, Brooklyn                  47
# Chelsea, Midtown Manhattan, Manhattan                  47
# Downtown Brooklyn, Northwestern Brooklyn, Brooklyn     45
# Rose Hill, Kips Bay, Midtown Manhattan, Manhattan      42
# Tribeca, Downtown Manhattan, Manhattan                 41
# East Harlem, Upper Manhattan, Manhattan                39
# Gramercy Park, Midtown Manhattan, Manhattan            38
# East Williamsburg, Williamsburg, Northern Brook...     36
# Turtle Bay, Midtown East, Midtown Manhattan, Ma...     34
# Williamsburg, Northern Brooklyn, Brooklyn              34
# Alphabet City, East Village, Downtown Manhattan...     33
# Theater District, Midtown Manhattan, Manhattan         31
# Flatbush, Central Brooklyn, Brooklyn                   29
# Manhattan Valley, Upper West Side, Upper Manhat...     26
# Greenpoint, Northern Brooklyn, Brooklyn                26
# Crown Heights, Central Brooklyn, Brooklyn              25
# Kips Bay, Midtown Manhattan, Manhattan                 22
# Astoria, Northwestern Queens, Queens                   22
# Washington Heights, Upper Manhattan, Manhattan         21
# Lower East Side, Downtown Manhattan, Manhattan         20
# ...                                                   ...
# Central Slope, Park Slope, South Brooklyn, Broo...      3
# Prospect Lefferts Gardens, Flatbush, Central Br...      3
# Morningside Heights, West Harlem, Upper Manhatt...      3
# Hudson Square, SoHo, Downtown Manhattan, Manhattan      3
# Kew Gardens Hills, Northeastern Queens, Queens          3
# Ocean Hill, Central Brooklyn, Brooklyn                  3
# Tudor City, Midtown East, Midtown Manhattan, Ma...      3
# Homecrest, Sheepshead Bay, Southern Brooklyn, B...      3
# Jackson Heights, Northwestern Queens, Queens            2
# Murray Hill, Queens, Flushing, Northeastern Que...      2
# Briarwood, Southeastern Queens, Queens                  2
# Kensington, Central Brooklyn, Brooklyn                  2
# Auburndale, Northeastern Queens, Queens                 2
# Flushing, Northeastern Queens, Queens                   2
# Bayside, Northeastern Queens, Queens                    2
# Ocean Parkway, Midwood, Central Brooklyn, Brooklyn      2
# Upper West Side, Manhattan                              1
# Wingate, East Flatbush, Central Brooklyn, Brooklyn      1
# Ditmars, Astoria, Northwestern Queens, Queens           1
# Brighton Beach, Southern Brooklyn, Brooklyn             1
# Bensonhurst, Southwestern Brooklyn, Brooklyn            1
# Central Park, Upper Manhattan, Manhattan                1
# Forest Hills, Northwestern Queens, Queens               1
# Steinway, Astoria, Northwestern Queens, Queens          1
# Richmond Hill, Southwestern Queens, Queens              1
# Gravesend, Southern Brooklyn, Brooklyn                  1
# Highland Park, Cypress Hills, Eastern Brooklyn,...      1
# Maspeth, Northwestern Queens, Queens                    1
# Manhattanville, West Harlem, Upper Manhattan, M...      1
# Glendale, Northwestern Queens, Queens                   1
#
# [107 rows x 1 columns]

# %%
rent_listing_df.groupby('neighborhood')['rent'].mean().to_frame('mean').sort_values(by='mean', ascending=False)
# Out:
#                                                             mean
# neighborhood
# Lenox Hill, Upper East Side, Upper Manhattan, M...  14310.714286
# Hudson Square, SoHo, Downtown Manhattan, Manhattan   9550.000000
# Midtown East, Midtown Manhattan, Manhattan           7914.400000
# Flatiron District, Midtown Manhattan, Manhattan      7273.400000
# Central Park, Upper Manhattan, Manhattan             6590.000000
# Lincoln Square, Upper West Side, Upper Manhatta...   6468.333333
# Battery Park City, Downtown Manhattan, Manhattan     6278.583333
# NoMad, Midtown Manhattan, Manhattan                  6185.375000
# SoHo, Downtown Manhattan, Manhattan                  6085.833333
# Lower East Side, Downtown Manhattan, Manhattan       5982.550000
# Tribeca, Downtown Manhattan, Manhattan               5676.365854
# Garment District, Midtown Manhattan, Manhattan       5671.000000
# Stuyvesant Town - Peter Cooper Village, Midtown...   5135.125000
# Upper West Side, Manhattan                           5100.000000
# Chelsea, Midtown Manhattan, Manhattan                5073.361702
# Little Italy, Downtown Manhattan, Manhattan          4975.000000
# West Village, Downtown Manhattan, Manhattan          4879.910714
# Two Bridges, Downtown Manhattan, Manhattan           4877.000000
# Theater District, Midtown Manhattan, Manhattan       4843.161290
# Sutton Place, Midtown East, Midtown Manhattan, ...   4766.411765
# Upper West Side, Upper Manhattan, Manhattan          4761.906250
# Greenwich Village, Downtown Manhattan, Manhattan     4694.333333
# Carnegie Hill, Upper East Side, Upper Manhattan...   4375.000000
# Murray Hill, Midtown Manhattan, Manhattan            4329.208333
# Gramercy Park, Midtown Manhattan, Manhattan          4319.236842
# Financial District, Downtown Manhattan, Manhattan    4311.118280
# Bowery, Downtown Manhattan, Manhattan                4278.500000
# Upper East Side, Upper Manhattan, Manhattan          4254.712963
# NoHo, Downtown Manhattan, Manhattan                  4208.333333
# Roosevelt Island, Manhattan                          4112.500000
# ...                                                          ...
# Highland Park, Cypress Hills, Eastern Brooklyn,...   2600.000000
# Kensington, Central Brooklyn, Brooklyn               2588.000000
# Prospect Lefferts Gardens, Flatbush, Central Br...   2560.666667
# Steinway, Astoria, Northwestern Queens, Queens       2550.000000
# Bayside, Northeastern Queens, Queens                 2525.000000
# Gravesend, Southern Brooklyn, Brooklyn               2500.000000
# Sunnyside, Long Island City, Northwestern Queen...   2395.000000
# Kew Gardens, Northeastern Queens, Queens             2361.400000
# Flushing, Northeastern Queens, Queens                2347.500000
# Wingate, East Flatbush, Central Brooklyn, Brooklyn   2300.000000
# Forest Hills, Northwestern Queens, Queens            2300.000000
# Crown Heights, Central Brooklyn, Brooklyn            2294.400000
# Hudson Heights, Washington Heights, Upper Manha...   2285.400000
# Weeksville, Crown Heights, Central Brooklyn, Br...   2216.500000
# Greenwood Heights, South Brooklyn, Brooklyn          2183.571429
# Sunset Park, South Brooklyn, Brooklyn                2181.666667
# Jamaica, Southeastern Queens, Queens                 2181.250000
# Jackson Heights, Northwestern Queens, Queens         2150.000000
# Tudor City, Midtown East, Midtown Manhattan, Ma...   2105.000000
# Briarwood, Southeastern Queens, Queens               2100.000000
# Bensonhurst, Southwestern Brooklyn, Brooklyn         2000.000000
# Inwood, Upper Manhattan, Manhattan                   1985.000000
# Auburndale, Northeastern Queens, Queens              1967.500000
# Brighton Beach, Southern Brooklyn, Brooklyn          1950.000000
# Ditmars, Astoria, Northwestern Queens, Queens        1850.000000
# Fort George, Washington Heights, Upper Manhatta...   1766.500000
# Richmond Hill, Southwestern Queens, Queens           1675.000000
# Murray Hill, Queens, Flushing, Northeastern Que...   1675.000000
# Maspeth, Northwestern Queens, Queens                 1600.000000
# Homecrest, Sheepshead Bay, Southern Brooklyn, B...   1600.000000
#
# [107 rows x 1 columns]

# %%
from geopy import ArcGIS

# %%
nom = ArcGIS()

# %%
from geopy.exc import GeocoderTimedOut

def do_geocode(address):
    try:
        return nom.geocode(address)
    except GeocoderTimedOut:
        time.sleep(1.25)
        return do_geocode(address)

# %%
rent_listing_df['location'] = rent_listing_df['neighborhood'].apply(do_geocode)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-9ee4aae8959d> in <module>
# ----> 1 rent_listing_df['location'] = rent_listing_df['neighborhood'].apply(do_geocode)
#
# D:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-30-f5e0f1164290> in do_geocode(address)
#       3 def do_geocode(address):
#       4     try:
# ----> 5         return nom.geocode(address)
#       6     except GeocoderTimedOut:
#       7         return do_geocode(address)
#
# D:\Anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in geocode(self, query, exactly_one, timeout, out_fields)
#     193         url = "?".join((self.api, urlencode(params)))
#     194         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
# --> 195         response = self._call_geocoder(url, timeout=timeout)
#     196
#     197         # Handle any errors; recursing in the case of an expired token.
#
# D:\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     353
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#     357             message = (
#
# D:\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# D:\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# D:\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# D:\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# D:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# D:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# D:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# D:\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# D:\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# D:\Anaconda3\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# D:\Anaconda3\lib\http\client.py in connect(self)
#    1382             "Connect to a host on a given (SSL) port."
#    1383
# -> 1384             super().connect()
#    1385
#    1386             if self._tunnel_host:
#
# D:\Anaconda3\lib\http\client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# D:\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
rent_listing_df['latitude'] = rent_listing_df['location'].apply(lambda x : x.latitude if x else None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1565450c2b5e> in <module>
# ----> 1 rent_listing_df['latitude'] = rent_listing_df['neighborhood'].apply(lambda x : x.latitude if x else None)
#
# D:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-25-1565450c2b5e> in <lambda>(x)
# ----> 1 rent_listing_df['latitude'] = rent_listing_df['neighborhood'].apply(lambda x : x.latitude if x else None)
#
# AttributeError: 'str' object has no attribute 'latitude'

# %%
rent_listing_df['longitude'] = rent_listing_df['location'].apply(lambda x : x.longitude if x else None)
