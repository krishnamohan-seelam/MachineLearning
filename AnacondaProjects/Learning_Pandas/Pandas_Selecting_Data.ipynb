# %%
import pandas as pd

# %%
import pathlib

# %%
filename = 'data-zillow.csv'
filepath  = pathlib.Path().cwd().joinpath('data')
filepath =filepath.joinpath(filename)

# %%
df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
df_profile = df.describe(include="all").T

# %%
df_profile['null']= df.isnull().sum()

# %%
df_profile
# Out:
#             count unique          top   freq     mean     std    min      25%  \
# Date        10830      1   2017-05-31  10830      NaN     NaN    NaN      NaN
# RegionID    10830    NaN          NaN    NaN  84344.8  125680   3301  19346.2
# RegionName  10830   8260  Springfield     16      NaN     NaN    NaN      NaN
# State       10830     49           PA   1208      NaN     NaN    NaN      NaN
# Metro       10256    566     New York    648      NaN     NaN    NaN      NaN
# County      10830    930   Washington    189      NaN     NaN    NaN      NaN
# SizeRank    10830    NaN          NaN    NaN   5414.5  3126.5      0  2707.25
# Zhvi        10830    NaN          NaN    NaN   250308  256558  37400   126900
#
#                 50%      75%         max  null
# Date            NaN      NaN         NaN     0
# RegionID    35444.5  52608.2      737791     0
# RegionName      NaN      NaN         NaN     0
# State           NaN      NaN         NaN     0
# ...

# %%
df['Address'] = df.County + ', ' + df.Metro + ', ' + df.State

# %%
df.loc[7,:]
# Out:
# Date                             2017-05-31
# RegionID                              38128
# RegionName                           Dallas
# State                                    TX
# Metro                     Dallas-Fort Worth
# County                               Dallas
# SizeRank                                  7
# Zhvi                                 164700
# Address       Dallas, Dallas-Fort Worth, TX
# Name: 7, dtype: object

# %%
df.loc[7,['Date','RegionName']]
# Out:
# Date          2017-05-31
# RegionName        Dallas
# Name: 7, dtype: object

# %% [markdown]
# ####  Selecting values from a range of rows and all columns

# %%
df.loc[202:207,]
# Out:
#            Date  RegionID   RegionName State                           Metro  \
# 202  2017-05-31      5914     Metairie    LA                     New Orleans
# 203  2017-05-31     47570  Santa Maria    CA       Santa Maria-Santa Barbara
# 204  2017-05-31     45888    Inglewood    CA  Los Angeles-Long Beach-Anaheim
# 205  2017-05-31     33252       Orange    CA  Los Angeles-Long Beach-Anaheim
# 206  2017-05-31      6155    New Haven    CT                       New Haven
# 207  2017-05-31     44821      Cumming    GA                         Atlanta
#
#             County  SizeRank    Zhvi  \
# 202      Jefferson       202  232700
# 203  Santa Barbara       203  354600
# 204    Los Angeles       204  470600
# 205         Orange       205  652000
# 206      New Haven       206  161200
# 207        Forsyth       207  281800
#
#                                              Address
# 202                       Jefferson, New Orleans, LA
# ...

# %%
# non-contiguous rows
df.loc[[5,10,15],:]
# Out:
#           Date  RegionID     RegionName State          Metro         County  \
# 5   2017-05-31     18959      Las Vegas    NV      Las Vegas          Clark
# 10  2017-05-31     20330  San Francisco    CA  San Francisco  San Francisco
# 15  2017-05-31     24043      Charlotte    NC      Charlotte    Mecklenburg
#
#     SizeRank     Zhvi                           Address
# 5          5   216500              Clark, Las Vegas, NV
# 10        10  1194300  San Francisco, San Francisco, CA
# 15        15   183800        Mecklenburg, Charlotte, NC

# %%
df[df['County']=='Queens'] # same as   df.loc[df['County']=='Queens'] # same as
# Out:
#          Date  RegionID RegionName State     Metro  County  SizeRank    Zhvi  \
# 0  2017-05-31      6181   New York    NY  New York  Queens         0  672400
#
#                 Address
# 0  Queens, New York, NY

# %%
df.sort_values('Metro').tail()
# Out:
#              Date  RegionID RegionName State Metro     County  SizeRank  \
# 10764  2017-05-31     35349     Fraser    CO   NaN      Grand     10764
# 10768  2017-05-31     17816    Dresser    WI   NaN       Polk     10768
# 10774  2017-05-31     34232   Tamworth    NH   NaN    Carroll     10774
# 10822  2017-05-31     18317  Goldsboro    MD   NaN   Caroline     10822
# 10825  2017-05-31     26077    Nehalem    OR   NaN  Tillamook     10825
#
#          Zhvi Address
# 10764  274500     NaN
# 10768  189900     NaN
# 10774  164100     NaN
# 10822  175700     NaN
# 10825  392200     NaN

# %% [markdown]
# #### Filtering rows of a pandas DataFrame

# %%
filtered_df = df.filter(regex='Region', axis=1) 
filtered_df.head()
# Out:
#    RegionID    RegionName
# 0      6181      New York
# 1     12447   Los Angeles
# 2     17426       Chicago
# 3     13271  Philadelphia
# 4     40326       Phoenix

# %%
df[df['Zhvi'] >= 1000000].head()
# Out:
#            Date  RegionID     RegionName State          Metro         County  \
# 10   2017-05-31     20330  San Francisco    CA  San Francisco  San Francisco
# 181  2017-05-31     54626      Sunnyvale    CA       San Jose    Santa Clara
# 234  2017-05-31     13713    Santa Clara    CA       San Jose    Santa Clara
# 238  2017-05-31     16992       Berkeley    CA  San Francisco        Alameda
# 308  2017-05-31     13699      San Mateo    CA  San Francisco      San Mateo
#
#      SizeRank     Zhvi                           Address
# 10         10  1194300  San Francisco, San Francisco, CA
# 181       181  1509300         Santa Clara, San Jose, CA
# 234       234  1071500         Santa Clara, San Jose, CA
# 238       238  1102000        Alameda, San Francisco, CA
# 308       308  1198300      San Mateo, San Francisco, CA

# %% [markdown]
# #### Filtering based on multiple conditions – AND (&), OR(|)

# %%
df[(df['Zhvi'] >= 1000000)&  (df['State'] == 'NY')].head()
# Out:
#             Date  RegionID  RegionName State     Metro       County  SizeRank  \
# 1132  2017-05-31     18375  Great Neck    NY  New York       Nassau      1132
# 2405  2017-05-31     54333   Scarsdale    NY  New York  Westchester      2405
# 2619  2017-05-31     47495         Rye    NY  New York  Westchester      2619
# 3032  2017-05-31     25725   Manhasset    NY  New York       Nassau      3032
# 3064  2017-05-31     18955   Larchmont    NY  New York  Westchester      3064
#
#          Zhvi                    Address
# 1132  1235800       Nassau, New York, NY
# 2405  1468100  Westchester, New York, NY
# 2619  1736400  Westchester, New York, NY
# 3032  1483400       Nassau, New York, NY
# 3064  1052200  Westchester, New York, NY

# %% [markdown]
# #### Filtering using the isin method

# %%
df[df['Metro'].isin(['New York','San Francisco'])].head()
# Out:
#           Date  RegionID     RegionName State          Metro         County  \
# 0   2017-05-31      6181       New York    NY       New York         Queens
# 10  2017-05-31     20330  San Francisco    CA  San Francisco  San Francisco
# 38  2017-05-31     13072        Oakland    CA  San Francisco        Alameda
# 63  2017-05-31     12970         Newark    NJ       New York          Essex
# 72  2017-05-31     25320    Jersey City    NJ       New York         Hudson
#
#     SizeRank     Zhvi                           Address
# 0          0   672400              Queens, New York, NY
# 10        10  1194300  San Francisco, San Francisco, CA
# 38        38   680100        Alameda, San Francisco, CA
# 63        63   232800               Essex, New York, NJ
# 72        72   380000              Hudson, New York, NJ

# %%
df[df['Metro'].isin({'State':['NY'] ,'Metro':['New York'] })].head()
# Out:
# Empty DataFrame
# Columns: [Date, RegionID, RegionName, State, Metro, County, SizeRank, Zhvi, Address]
# Index: []

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
categorical = ['State','Metro','RegionName','County']

# %%
# fig, ax = plt.subplots(2, 4, figsize=(20, 10))
# for variable, subplot in zip(categorical, ax.flatten()):
#     sns.countplot(df[variable], ax=subplot)
#     for label in subplot.get_xticklabels():
#         label.set_rotation(90)
