# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### NA handling methods
# ##### Remove NA rows

# %%
from numpy import nan as NA

# %%
titanic = pd.read_csv('data/kaggle_titanic/train.csv')
titanic[titanic['Cabin'].isnull()].head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
def check_null(dataset):
    null_sum = dataset.isnull().sum()[dataset.isnull().sum()>0]
    print("<{0} {1} {0}>".format("="*35, "Dataset null value count"))
    print(null_sum.sort_values(ascending=False))
    print("<{0}>".format("="*35))

check_null(titanic)
# Out:
# <=================================== Dataset null value count ===================================>
# Cabin       687
# Age         177
# Embarked      2
# dtype: int64
# <===================================>

# %%
titanic['Nulls_Per_Row']=titanic.isnull().sum(axis=1)

# %%
titanic[titanic['Nulls_Per_Row']==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# 140          141         0       3
# 154          155         0       3
# 158          159         0       3
# 159          160         0       3
# 168          169         0       1
# ..           ...       ...     ...
# 674          675         0       2
# 680          681         0       3
# 692          693         1       3
# 697          698         1       3
# 709          710         1       3
# 718          719         0       3
# 727          728         1       3
# 732          733         0       2
# 738          739         0       3
# 739          740         0       3
# 760          761         0       3
# 766          767         0       1
# 768          769         0       3
# 773          774         0       3
# 778          779         0       3
# 783          784         0       3
# 790          791         0       3
# 792          793         0       3
# 793          794         0       1
# 825          826         0       3
# 826          827         0       3
# 828          829         1       3
# 832          833         0       3
# 837          838         0       3
# 846          847         0       3
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 5                                     Moran, Mr. James    male  NaN      0
# 17                        Williams, Mr. Charles Eugene    male  NaN      0
# 19                             Masselmani, Mrs. Fatima  female  NaN      0
# 26                             Emir, Mr. Farred Chehab    male  NaN      0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# 29                                 Todoroff, Mr. Lalio    male  NaN      0
# 32                            Glynn, Miss. Mary Agatha  female  NaN      0
# 36                                    Mamee, Mr. Hanna    male  NaN      0
# 42                                 Kraeff, Mr. Theodor    male  NaN      0
# 45                            Rogers, Mr. William John    male  NaN      0
# 46                                   Lennon, Mr. Denis    male  NaN      1
# 47                           O'Driscoll, Miss. Bridget  female  NaN      0
# 48                                 Samaan, Mr. Youssef    male  NaN      2
# 64                               Stewart, Mr. Albert A    male  NaN      0
# 65                            Moubarek, Master. Gerios    male  NaN      1
# 76                                   Staneff, Mr. Ivan    male  NaN      0
# 77                            Moutal, Mr. Rahamin Haim    male  NaN      0
# 82                      McDermott, Miss. Brigdet Delia  female  NaN      0
# 87                       Slocovski, Mr. Selman Francis    male  NaN      0
# 95                         Shorney, Mr. Charles Joseph    male  NaN      0
# 101                   Petroff, Mr. Pastcho ("Pentcho")    male  NaN      0
# 107                             Moss, Mr. Albert Johan    male  NaN      0
# 109                                Moran, Miss. Bertha  female  NaN      1
# 121                         Moore, Mr. Leonard Charles    male  NaN      0
# 126                                McMahon, Mr. Martin    male  NaN      0
# 140                      Boulos, Mrs. Joseph (Sultana)  female  NaN      0
# 154                              Olsen, Mr. Ole Martin    male  NaN      0
# 158                                Smiljanic, Mr. Mile    male  NaN      0
# 159                         Sage, Master. Thomas Henry    male  NaN      8
# 168                                Baumann, Mr. John D    male  NaN      0
# ..                                                 ...     ...  ...    ...
# 674                         Watson, Mr. Ennis Hastings    male  NaN      0
# 680                                Peters, Miss. Katie  female  NaN      0
# 692                                       Lam, Mr. Ali    male  NaN      0
# 697                   Mullens, Miss. Katherine "Katie"  female  NaN      0
# 709  Moubarek, Master. Halim Gonios ("William George")    male  NaN      1
# 718                                McEvoy, Mr. Michael    male  NaN      0
# 727                           Mannion, Miss. Margareth  female  NaN      0
# 732                               Knight, Mr. Robert J    male  NaN      0
# 738                                 Ivanoff, Mr. Kanio    male  NaN      0
# 739                                 Nankoff, Mr. Minko    male  NaN      0
# 760                                 Garfirth, Mr. John    male  NaN      0
# 766                          Brewe, Dr. Arthur Jackson    male  NaN      0
# 768                                Moran, Mr. Daniel J    male  NaN      1
# 773                                    Elias, Mr. Dibo    male  NaN      0
# 778                            Kilgannon, Mr. Thomas J    male  NaN      0
# 783                             Johnston, Mr. Andrew G    male  NaN      1
# 790                           Keane, Mr. Andrew "Andy"    male  NaN      0
# 792                            Sage, Miss. Stella Anna  female  NaN      8
# 793                           Hoyt, Mr. William Fisher    male  NaN      0
# 825                                    Flynn, Mr. John    male  NaN      0
# 826                                       Lam, Mr. Len    male  NaN      0
# 828                       McCormack, Mr. Thomas Joseph    male  NaN      0
# 832                                     Saad, Mr. Amin    male  NaN      0
# 837                                Sirota, Mr. Maurice    male  NaN      0
# 846                           Sage, Mr. Douglas Bullen    male  NaN      8
# 859                                   Razi, Mr. Raihed    male  NaN      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 868                        van Melkebeke, Mr. Philemon    male  NaN      0
# 878                                 Laleff, Mr. Kristo    male  NaN      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
#
#      Parch           Ticket     Fare Cabin Embarked  Nulls_Per_Row
# 5        0           330877   8.4583   NaN        Q              2
# 17       0           244373  13.0000   NaN        S              2
# 19       0             2649   7.2250   NaN        C              2
# 26       0             2631   7.2250   NaN        C              2
# 28       0           330959   7.8792   NaN        Q              2
# 29       0           349216   7.8958   NaN        S              2
# 32       0           335677   7.7500   NaN        Q              2
# 36       0             2677   7.2292   NaN        C              2
# 42       0           349253   7.8958   NaN        C              2
# 45       0  S.C./A.4. 23567   8.0500   NaN        S              2
# 46       0           370371  15.5000   NaN        Q              2
# 47       0            14311   7.7500   NaN        Q              2
# 48       0             2662  21.6792   NaN        C              2
# 64       0         PC 17605  27.7208   NaN        C              2
# 65       1             2661  15.2458   NaN        C              2
# 76       0           349208   7.8958   NaN        S              2
# 77       0           374746   8.0500   NaN        S              2
# 82       0           330932   7.7875   NaN        Q              2
# 87       0  SOTON/OQ 392086   8.0500   NaN        S              2
# 95       0           374910   8.0500   NaN        S              2
# 101      0           349215   7.8958   NaN        S              2
# 107      0           312991   7.7750   NaN        S              2
# 109      0           371110  24.1500   NaN        Q              2
# 121      0        A4. 54510   8.0500   NaN        S              2
# 126      0           370372   7.7500   NaN        Q              2
# 140      2             2678  15.2458   NaN        C              2
# 154      0        Fa 265302   7.3125   NaN        S              2
# 158      0           315037   8.6625   NaN        S              2
# 159      2         CA. 2343  69.5500   NaN        S              2
# 168      0         PC 17318  25.9250   NaN        S              2
# ..     ...              ...      ...   ...      ...            ...
# 674      0           239856   0.0000   NaN        S              2
# 680      0           330935   8.1375   NaN        Q              2
# 692      0             1601  56.4958   NaN        S              2
# 697      0            35852   7.7333   NaN        Q              2
# 709      1             2661  15.2458   NaN        C              2
# 718      0            36568  15.5000   NaN        Q              2
# 727      0            36866   7.7375   NaN        Q              2
# 732      0           239855   0.0000   NaN        S              2
# 738      0           349201   7.8958   NaN        S              2
# 739      0           349218   7.8958   NaN        S              2
# 760      0           358585  14.5000   NaN        S              2
# 766      0           112379  39.6000   NaN        C              2
# 768      0           371110  24.1500   NaN        Q              2
# 773      0             2674   7.2250   NaN        C              2
# 778      0            36865   7.7375   NaN        Q              2
# 783      2       W./C. 6607  23.4500   NaN        S              2
# 790      0            12460   7.7500   NaN        Q              2
# 792      2         CA. 2343  69.5500   NaN        S              2
# 793      0         PC 17600  30.6958   NaN        C              2
# 825      0           368323   6.9500   NaN        Q              2
# 826      0             1601  56.4958   NaN        S              2
# 828      0           367228   7.7500   NaN        Q              2
# 832      0             2671   7.2292   NaN        C              2
# 837      0           392092   8.0500   NaN        S              2
# 846      2         CA. 2343  69.5500   NaN        S              2
# 859      0             2629   7.2292   NaN        C              2
# 863      2         CA. 2343  69.5500   NaN        S              2
# 868      0           345777   9.5000   NaN        S              2
# 878      0           349217   7.8958   NaN        S              2
# 888      2       W./C. 6607  23.4500   NaN        S              2
#
# [158 rows x 13 columns]

# %% [markdown]
# #### Drop Nulls - Not a wise option

# %%
print("% Data lost due to dropping of nulls :{0}".format( 100 -(titanic.dropna(axis=0).shape[0]/titanic.shape[0] )*100))
# Out:
# % Data lost due to dropping of nulls :79.46127946127946

# %% [markdown]
# #### Preferred method for imputing nulls
# #### mode for  catergorical features -- Cabin,Embarked
# #### mean/median for continuous features --Age

# %%
titanic['Embarked'].mode()
titanic['Embarked'].fillna('S',inplace=True)
check_null(titanic)
# Out:
# <=================================== Dataset null value count ===================================>
# Cabin    687
# Age      177
# dtype: int64
# <===================================>

# %%
titanic['Age'].median()
titanic['Age'].fillna(28,inplace=True)
check_null(titanic)
# Out:
# <=================================== Dataset null value count ===================================>
# Cabin    687
# dtype: int64
# <===================================>

# %%
titanic['Cabin'].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# dtype: object

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon',
                              'Pastrami', 'corned beef', 'Bacon',
                              'pastrami', 'honey ham', 'nova lox'],
                     'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
  'bacon': 'pig',
  'pulled pork': 'pig',
  'pastrami': 'cow',
  'corned beef': 'cow',
  'honey ham': 'pig',
  'nova lox': 'salmon'
}
lowercased = data['food'].str.lower()
data['animal'] = lowercased.map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['animal_map']=data['food'].map(lambda x: meat_to_animal[x.lower()])
data
# Out:
#           food  ounces  animal animal_map
# 0        bacon     4.0     pig        pig
# 1  pulled pork     3.0     pig        pig
# 2        bacon    12.0     pig        pig
# 3     Pastrami     6.0     cow        cow
# 4  corned beef     7.5     cow        cow
# 5        Bacon     8.0     pig        pig
# 6     pastrami     3.0     cow        cow
# 7    honey ham     5.0     pig        pig
# 8     nova lox     6.0  salmon     salmon

# %% [markdown]
# #### Discretization and Binning

# %%
age_bins =[18, 25, 35, 60, 100]
agebin_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']
titanic['Age_Bins'] = pd.cut(titanic['Age'], age_bins,labels =agebin_names)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Nulls_Per_Row    Age_Bins
# 0      0         A/5 21171   7.2500   NaN        S              1       Youth
# 1      0          PC 17599  71.2833   C85        C              0  MiddleAged
# 2      0  STON/O2. 3101282   7.9250   NaN        S              1  YoungAdult
# 3      0            113803  53.1000  C123        S              0  YoungAdult
# 4      0            373450   8.0500   NaN        S              1  YoungAdult
