# %%
import pandas as pd

# %%
dataframe  = pd.DataFrame()

dataframe['Name'] = ["ChotaBheem","Chutki","Kaalia"]
dataframe["Age"] = [8,6,8]
dataframe["City"] =["Dholakpur","Dholakpur","Dholakpur"]

dataframe
# Out:
#          Name  Age       City
# 0  ChotaBheem    8  Dholakpur
# 1      Chutki    6  Dholakpur
# 2      Kaalia    8  Dholakpur

# %%
new_person = pd.Series(['Raju',3, "Dholakpur"], index=['Name','Age','City'])
dataframe.append(new_person,ignore_index =True)
# Out:
#          Name  Age       City
# 0  ChotaBheem    8  Dholakpur
# 1      Chutki    6  Dholakpur
# 2      Kaalia    8  Dholakpur
# 3        Raju    3  Dholakpur

# %%
input_file = r"data\income\adult_train.csv"
input_dataset = pd.read_csv(input_file,delimiter=';')
input_dataset.head(5)
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
input_dataset['BinaryTarget']  = input_dataset['Target'].apply(lambda x : 1 if x.strip() == '>50K' else 0 )

# %%
input_dataset['Target'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
input_dataset['BinaryTarget'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
input_dataset.head(5)
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial_Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target  \
# ...
